# Processing Record 6 of Set 4 | nova sintra
# Processing Record 7 of Set 4 | st. john's
# Processing Record 8 of Set 4 | es castell
# Processing Record 9 of Set 4 | dalhart
# Processing Record 10 of Set 4 | fort st. john
# Processing Record 11 of Set 4 | zhenlai
# Processing Record 12 of Set 4 | selfoss
# Processing Record 13 of Set 4 | otjimbingwe
# Processing Record 14 of Set 4 | wuxi
# Processing Record 15 of Set 4 | prieska
# Processing Record 16 of Set 4 | jinghong
# Processing Record 17 of Set 4 | carloforte
# Processing Record 18 of Set 4 | yichang
# Processing Record 19 of Set 4 | constantia
# Processing Record 20 of Set 4 | dudinka
# Processing Record 21 of Set 4 | tomatlan
# Processing Record 22 of Set 4 | i-n-salah
# Processing Record 23 of Set 4 | queenstown
# Processing Record 24 of Set 4 | ash shatrah
# Processing Record 25 of Set 4 | port alfred
# Processing Record 26 of Set 4 | lanchyn
# Processing Record 27 of Set 4 | tulunan
# Processing Record 28 of Set 4 | kirakira
# Processing Record 29 of Set 4 | nuku'alofa
# Processing Record 30 of Set 4 | qaqortoq
# Processing Record 31 of Set 4 | taganrog
# Processing Record 32 of Set 4 | el granada
# Processing Record 33 of Set 4 | downpatrick
# Processing Record 34 of Set 4 | tiksi
# Processing Record 35 of Set 4 | gaiman
# Processing Record 36 of Set 4 | chita
# Processing Record 37 of Set 4 | el calafate
# Processing Record 38 of Set 4 | ola
# Processing Record 39 of Set 4 | cruzeiro do sul
# Processing Record 40 of Set 4 | sai kung
# Processing Record 41 of Set 4 | thunder bay
# Processing Record 42 of Set 4 | harstad
# Processing Record 43 of Set 4 | saint-francois
# Processing Record 44 of Set 4 | port lincoln
# Processing Record 45 of Set 4 | nola
# Processing Record 46 of Set 4 | broome
# Processing Record 47 of Set 4 | pauini
# Processing Record 48 of Set 4 | egilsstadir
# Processing Record 49 of Set 4 | kingston
# Processing Record 0 of Set 5 | kapuskasing
# Processing Record 1 of Set 5 | inari
# Processing Record 2 of Set 5 | usogorsk
# Processing Record 3 of Set 5 | kruisfontein
# Processing Record 4 of Set 5 | kwang binh
# Processing Record 5 of Set 5 | peterhead
# Processing Record 6 of Set 5 | san juan del cesar
# Processing Record 7 of Set 5 | crane
# Processing Record 8 of Set 5 | the bottom
# Processing Record 9 of Set 5 | east london
# Processing Record 10 of Set 5 | kuta
# Processing Record 11 of Set 5 | callao
# Processing Record 12 of Set 5 | la romana
# Processing Record 13 of Set 5 | gulf shores
# Processing Record 14 of Set 5 | santa ana de yacuma
# Processing Record 15 of Set 5 | palikir - national government center
# Processing Record 16 of Set 5 | vorkuta
# Processing Record 17 of Set 5 | akjoujt
# Processing Record 18 of Set 5 | labrador city
# Processing Record 19 of Set 5 | martapura
# Processing Record 20 of Set 5 | toga village
# City not found. Skipping...
# Processing Record 21 of Set 5 | jutai
# Processing Record 22 of Set 5 | matoury
# Processing Record 23 of Set 5 | ilulissat
# Processing Record 24 of Set 5 | pitimbu
# Processing Record 25 of Set 5 | slave lake
# Processing Record 26 of Set 5 | san julian
# Processing Record 27 of Set 5 | mili
# Processing Record 28 of Set 5 | ji parana
# City not found. Skipping...
# Processing Record 29 of Set 5 | vingt cinq
# City not found. Skipping...
# Processing Record 30 of Set 5 | cable beach
# City not found. Skipping...
# Processing Record 31 of Set 5 | asau village
# City not found. Skipping...
# Processing Record 32 of Set 5 | wailua homesteads
# Processing Record 33 of Set 5 | al-hamdaniya
# Processing Record 34 of Set 5 | kavieng
# Processing Record 35 of Set 5 | souillac
# Processing Record 36 of Set 5 | severnoye
# Processing Record 37 of Set 5 | kargasok
# Processing Record 38 of Set 5 | mena
# Processing Record 39 of Set 5 | vilyuchinsk
# Processing Record 40 of Set 5 | sevastopol
# Processing Record 41 of Set 5 | moog
# Processing Record 42 of Set 5 | iskateley
# Processing Record 43 of Set 5 | bargaal
# Processing Record 44 of Set 5 | kodiak
# Processing Record 45 of Set 5 | leh
# Processing Record 46 of Set 5 | alghero
# Processing Record 47 of Set 5 | paramirim
# Processing Record 48 of Set 5 | yar
# Processing Record 49 of Set 5 | le portel
# Processing Record 0 of Set 6 | tibanbang
# Processing Record 1 of Set 6 | enewetak
# Processing Record 2 of Set 6 | sheopur
# Processing Record 3 of Set 6 | verkhnevilyuysk
# Processing Record 4 of Set 6 | nagqu
# Processing Record 5 of Set 6 | friedland
# Processing Record 6 of Set 6 | shaoxing
# Processing Record 7 of Set 6 | hithadhoo
# Processing Record 8 of Set 6 | puerto san jose
# Processing Record 9 of Set 6 | mount isa
# Processing Record 10 of Set 6 | margaret river
# Processing Record 11 of Set 6 | hoogeveen
# Processing Record 12 of Set 6 | 'ohonua
# City not found. Skipping...
# Processing Record 13 of Set 6 | tshabong
# Processing Record 14 of Set 6 | isangel
# Processing Record 15 of Set 6 | saldanha
# Processing Record 16 of Set 6 | talcahuano
# Processing Record 17 of Set 6 | quimili
# Processing Record 18 of Set 6 | sola
# Processing Record 19 of Set 6 | kulhudhuffushi
# Processing Record 20 of Set 6 | matias romero
# Processing Record 21 of Set 6 | siwa oasis
# Processing Record 22 of Set 6 | tevragh zeina
# City not found. Skipping...
# Processing Record 23 of Set 6 | port elizabeth
# Processing Record 24 of Set 6 | gobabis
# Processing Record 25 of Set 6 | cloquet
# Processing Record 26 of Set 6 | nicoya
# Processing Record 27 of Set 6 | enna
# Processing Record 28 of Set 6 | lasem
# Processing Record 29 of Set 6 | la passe
# Processing Record 30 of Set 6 | afaahiti
# Processing Record 31 of Set 6 | puerto baquerizo moreno
# Processing Record 32 of Set 6 | inhambane
# Processing Record 33 of Set 6 | colonia
# Processing Record 34 of Set 6 | olonkinbyen
# Processing Record 35 of Set 6 | lewistown
# Processing Record 36 of Set 6 | umba
# Processing Record 37 of Set 6 | ilhabela
# Processing Record 38 of Set 6 | amarante do maranhao
# Processing Record 39 of Set 6 | brookings
# Processing Record 40 of Set 6 | luderitz
# Processing Record 41 of Set 6 | blenheim
# Processing Record 42 of Set 6 | dhidhdhoo
# Processing Record 43 of Set 6 | padang
# Processing Record 44 of Set 6 | nuuk
# Processing Record 45 of Set 6 | pekalongan
# Processing Record 46 of Set 6 | oliver
# Processing Record 47 of Set 6 | acapulco de juarez
# Processing Record 48 of Set 6 | agapovka
# Processing Record 49 of Set 6 | polyarnyy
# Processing Record 0 of Set 7 | santana do livramento
# Processing Record 1 of Set 7 | pangai
# Processing Record 2 of Set 7 | viedma
# Processing Record 3 of Set 7 | mata-utu
# Processing Record 4 of Set 7 | utrik
# Processing Record 5 of Set 7 | tolanaro
# Processing Record 6 of Set 7 | dubna
# Processing Record 7 of Set 7 | bubaque
# Processing Record 8 of Set 7 | fort bragg
# Processing Record 9 of Set 7 | wellington
# Processing Record 10 of Set 7 | haeju
# Processing Record 11 of Set 7 | tralee
# Processing Record 12 of Set 7 | cargados carajos
# City not found. Skipping...
# Processing Record 13 of Set 7 | campofelice di roccella
# Processing Record 14 of Set 7 | ta`u
# Processing Record 15 of Set 7 | mahina
# Processing Record 16 of Set 7 | nemuro
# Processing Record 17 of Set 7 | salym
# Processing Record 18 of Set 7 | puerto madero
# Processing Record 19 of Set 7 | ust-nera
# Processing Record 20 of Set 7 | miranpur katra
# Processing Record 21 of Set 7 | robore
# Processing Record 22 of Set 7 | hood river
# Processing Record 23 of Set 7 | tazacorte
# Processing Record 24 of Set 7 | phang nga
# Processing Record 25 of Set 7 | moro
# Processing Record 26 of Set 7 | thompson
# Processing Record 27 of Set 7 | vadso
# Processing Record 28 of Set 7 | santana
# Processing Record 29 of Set 7 | kijang
# Processing Record 30 of Set 7 | toledo
# Processing Record 31 of Set 7 | tchaourou
# Processing Record 32 of Set 7 | cabo san lucas
# Processing Record 33 of Set 7 | bintulu
# Processing Record 34 of Set 7 | aghstafa
# Processing Record 35 of Set 7 | masterton
# Processing Record 36 of Set 7 | rongelap
# Processing Record 37 of Set 7 | oppdal
# Processing Record 38 of Set 7 | borazjan
# Processing Record 39 of Set 7 | castanos
# Processing Record 40 of Set 7 | roxas
# Processing Record 41 of Set 7 | taperoa
# Processing Record 42 of Set 7 | burang
# Processing Record 43 of Set 7 | robertsport
# Processing Record 44 of Set 7 | anadyr
# Processing Record 45 of Set 7 | guankou
# Processing Record 46 of Set 7 | talnakh
# Processing Record 47 of Set 7 | aoulef
# Processing Record 48 of Set 7 | teluknaga
# Processing Record 49 of Set 7 | ghadamis
# Processing Record 0 of Set 8 | lazaro cardenas
# Processing Record 1 of Set 8 | caconda
# Processing Record 2 of Set 8 | port moresby
# Processing Record 3 of Set 8 | hancheng
# Processing Record 4 of Set 8 | lebu
# Processing Record 5 of Set 8 | umarkot
# Processing Record 6 of Set 8 | sassandra
# Processing Record 7 of Set 8 | sarkand
# Processing Record 8 of Set 8 | two rivers
# Processing Record 9 of Set 8 | tura
# Processing Record 10 of Set 8 | uturoa
# Processing Record 11 of Set 8 | saint-philippe
# Processing Record 12 of Set 8 | ulaangom
# Processing Record 13 of Set 8 | talakan
# Processing Record 14 of Set 8 | shushtar
# Processing Record 15 of Set 8 | nurota
# Processing Record 16 of Set 8 | suva
# Processing Record 17 of Set 8 | areia branca
# Processing Record 18 of Set 8 | pokhara
# Processing Record 19 of Set 8 | visby
# Processing Record 20 of Set 8 | laojunmiao
# Processing Record 21 of Set 8 | mount pearl
# Processing Record 22 of Set 8 | rehoboth
# Processing Record 23 of Set 8 | wajir
# Processing Record 24 of Set 8 | doma
# Processing Record 25 of Set 8 | quibala
# Processing Record 47 of Set 9 | vi thanh
# City not found. Skipping...
# Processing Record 48 of Set 9 | san angelo
# Processing Record 49 of Set 9 | kalianget
# Processing Record 0 of Set 10 | gebeit
# Processing Record 1 of Set 10 | ko pha ngan
# Processing Record 2 of Set 10 | nouadhibou
# Processing Record 3 of Set 10 | kitui
# Processing Record 4 of Set 10 | vangaindrano
# Processing Record 5 of Set 10 | malango
# Processing Record 6 of Set 10 | norfolk
# Processing Record 7 of Set 10 | al hufuf
# Processing Record 8 of Set 10 | port macquarie
# Processing Record 9 of Set 10 | antonio enes
# Processing Record 10 of Set 10 | san jose de jachal
# Processing Record 11 of Set 10 | newman
# Processing Record 12 of Set 10 | puerto carreno
# Processing Record 13 of Set 10 | sabang
# Processing Record 14 of Set 10 | guiuan
# Processing Record 15 of Set 10 | taltal
# Processing Record 16 of Set 10 | heihe
# Processing Record 17 of Set 10 | naracoorte
# Processing Record 18 of Set 10 | anzio
# Processing Record 19 of Set 10 | jasper
# Processing Record 20 of Set 10 | tateyama
# Processing Record 21 of Set 10 | vernon
# Processing Record 22 of Set 10 | muynoq
# Processing Record 23 of Set 10 | minas de marcona
# Processing Record 24 of Set 10 | borba
# Processing Record 25 of Set 10 | chaykovskiy
# Processing Record 26 of Set 10 | hassi messaoud
# Processing Record 27 of Set 10 | richards bay
# Processing Record 28 of Set 10 | manokwari
# Processing Record 29 of Set 10 | sebdou
# Processing Record 30 of Set 10 | severo-yeniseyskiy
# Processing Record 31 of Set 10 | gornopravdinsk
# Processing Record 32 of Set 10 | miles city
# Processing Record 33 of Set 10 | inirida
# Processing Record 34 of Set 10 | baruun-urt
# Processing Record 35 of Set 10 | qingdao
# Processing Record 36 of Set 10 | naha
# Processing Record 37 of Set 10 | hanceville
# Processing Record 38 of Set 10 | belmonte
# Processing Record 39 of Set 10 | magangue
# Processing Record 40 of Set 10 | cuyo
# Processing Record 41 of Set 10 | coari
# Processing Record 42 of Set 10 | betio village
# Processing Record 43 of Set 10 | riyadh
# Processing Record 44 of Set 10 | paita
# Processing Record 45 of Set 10 | ust-tsilma
# Processing Record 46 of Set 10 | atar
# Processing Record 47 of Set 10 | curaca
# Processing Record 48 of Set 10 | caqueza
# Processing Record 49 of Set 10 | cherdyn'
# Processing Record 0 of Set 11 | yuzhno-kurilsk
# Processing Record 1 of Set 11 | fort mcmurray
# Processing Record 2 of Set 11 | chengde
# Processing Record 3 of Set 11 | shitanjing
# Processing Record 4 of Set 11 | sisimiut
# Processing Record 5 of Set 11 | saint-leu
# Processing Record 6 of Set 11 | nikolayevsk-on-amure
# Processing Record 7 of Set 11 | bereznik
# Processing Record 8 of Set 11 | yangliuqing
# Processing Record 9 of Set 11 | metlili chaamba
# Processing Record 10 of Set 11 | san martin
# Processing Record 11 of Set 11 | tucuma
# Processing Record 12 of Set 11 | ad darb
# Processing Record 13 of Set 11 | velizh
# Processing Record 14 of Set 11 | saiha
# Processing Record 15 of Set 11 | lakatoro
# Processing Record 16 of Set 11 | camrose
# Processing Record 17 of Set 11 | cam pha mines
# Processing Record 18 of Set 11 | tenno
# Processing Record 19 of Set 11 | namibe
# Processing Record 20 of Set 11 | cusset
# Processing Record 21 of Set 11 | molepolole
# Processing Record 22 of Set 11 | safi
# Processing Record 23 of Set 11 | orapa
# Processing Record 24 of Set 11 | prince rupert
# Processing Record 25 of Set 11 | mingora
# Processing Record 26 of Set 11 | kerema
# Processing Record 27 of Set 11 | sona
# Processing Record 28 of Set 11 | boke
# Processing Record 29 of Set 11 | santo antonio
# Processing Record 30 of Set 11 | banff
# Processing Record 31 of Set 11 | dolores
# Processing Record 32 of Set 11 | wum
# Processing Record 33 of Set 11 | corumba
# Processing Record 34 of Set 11 | belyy yar
# Processing Record 35 of Set 11 | kalemie
# Processing Record 36 of Set 11 | okha
# Processing Record 37 of Set 11 | vilyuysk
# Processing Record 38 of Set 11 | howard springs
# Processing Record 39 of Set 11 | el carril
# Processing Record 40 of Set 11 | camiri
# Processing Record 41 of Set 11 | carentan
# Processing Record 42 of Set 11 | mizdah
# Processing Record 43 of Set 11 | bandarbeyla
# Processing Record 44 of Set 11 | kailua-kona
# Processing Record 45 of Set 11 | emporia
# Processing Record 46 of Set 11 | ulladulla
# Processing Record 47 of Set 11 | jijel
# Processing Record 48 of Set 11 | ialibu
# Processing Record 49 of Set 11 | saint-joseph
# Processing Record 0 of Set 12 | san carlos del zulia
# Processing Record 1 of Set 12 | mundri
# Processing Record 2 of Set 12 | spanish springs
# Processing Record 3 of Set 12 | soio
# Processing Record 4 of Set 12 | ouesso
# Processing Record 5 of Set 12 | hasaki
# Processing Record 6 of Set 12 | karratha
# Processing Record 7 of Set 12 | pineville
# Processing Record 8 of Set 12 | san juan
# Processing Record 9 of Set 12 | alenquer
# Processing Record 10 of Set 12 | jiuquan
# Processing Record 11 of Set 12 | nguigmi
# Processing Record 12 of Set 12 | oyo
# Processing Record 13 of Set 12 | lloydminster
# Processing Record 14 of Set 12 | khilok
# Processing Record 15 of Set 12 | jeronimo monteiro
# Processing Record 16 of Set 12 | castillos
# Processing Record 17 of Set 12 | trujillo
# Processing Record 18 of Set 12 | mahibadhoo
# Processing Record 19 of Set 12 | porto torres
# Processing Record 20 of Set 12 | huntsville
# Processing Record 21 of Set 12 | parras de la fuente
# Processing Record 22 of Set 12 | north battleford
# Processing Record 23 of Set 12 | kristinestad
# Processing Record 24 of Set 12 | knyaze-volkonskoye
# Processing Record 25 of Set 12 | menzelinsk
# Processing Record 26 of Set 12 | cacador
# Processing Record 27 of Set 12 | robit
# Processing Record 28 of Set 12 | chamical
# Processing Record 29 of Set 12 | kristiansund
# Processing Record 30 of Set 12 | arkhangel'sk
# Processing Record 31 of Set 12 | coahuayana de hidalgo
# Processing Record 32 of Set 12 | simsbury center
# Processing Record 33 of Set 12 | tadine
# Processing Record 34 of Set 12 | abaza
# Processing Record 35 of Set 12 | mozarlandia
# Processing Record 36 of Set 12 | kolonia
# Processing Record 37 of Set 12 | laguna
# Processing Record 38 of Set 12 | berezovyy
# Processing Record 39 of Set 12 | sliven
# Processing Record 40 of Set 12 | maitum
# Processing Record 41 of Set 12 | balakhta
# Processing Record 42 of Set 12 | maravatio de ocampo
# Processing Record 43 of Set 12 | constitucion
# Processing Record 44 of Set 12 | gallup
# Processing Record 45 of Set 12 | las lomitas
# Processing Record 46 of Set 12 | katsuren-haebaru
# Processing Record 47 of Set 12 | turpan
# Processing Record 48 of Set 12 | poyarkovo
# Processing Record 49 of Set 12 | sulak
# Processing Record 0 of Set 13 | quang ngai
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the cities weather data into a Pandas DataFrame
city_data_df = pd.DataFrame(city_data)

# Show Record Count
city_data_df.count()
# Out:
# City          581
# Lat           581
# Lng           581
# Max Temp      581
# Humidity      581
# Cloudiness    581
# Wind Speed    581
# Country       581
# Date          581
# dtype: int64

# %%
# Display sample data
city_data_df.head()
# Out:
#         City      Lat       Lng  Max Temp  Humidity  Cloudiness  Wind Speed  \
# 0       amga  60.8953  131.9608     -5.88        97         100        0.75
# 1     howrah  22.5892   88.3103     30.00        84          40        3.60
# 2     guilin  25.2819  110.2864     19.06        90           0        1.07
# 3   tazovsky  67.4667   78.7000    -11.20        98          99        2.02
# 4  grytviken -54.2811  -36.5092      3.33        95         100        1.85
#
#   Country        Date
# 0      RU  1681935785
# 1      IN  1681935786
# 2      CN  1681935786
# 3      RU  1681935487
# 4      GS  1681935482

# %%
# Export the City_Data into a csv
city_data_df.to_csv("output_data/cities.csv", index_label="City_ID")

# %%
# Read saved data
city_data_df = pd.read_csv("output_data/cities.csv", index_col="City_ID")

# Display sample data
city_data_df.head()
# Out:
#               City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 0             amga  60.8953  131.9608     -5.88        97         100
# 1           howrah  22.5892   88.3103     30.00        84          40
# 2           guilin  25.2819  110.2864     19.06        90           0
# 3         tazovsky  67.4667   78.7000    -11.20        98          99
# 4        grytviken -54.2811  -36.5092      3.33        95         100
#
#          Wind Speed Country        Date
# City_ID
# 0              0.75      RU  1681935785
# 1              3.60      IN  1681935786
# 2              1.07      CN  1681935786
# 3              2.02      RU  1681935487
# 4              1.85      GS  1681935482

# %% [markdown]
# ### Create the Scatter Plots Requested
#
# #### Latitude Vs. Temperature

# %%
# Build scatter plot for latitude vs. temperature
x_lat = city_data_df['Lat']
y_temp = city_data_df['Max Temp']



# Get the time from the first entry, to use on the chart title
data_time = time.ctime(city_data_df['Date'].max())

# Incorporate the other graph properties
fig1 = plt.figure()
plt.scatter(x_lat, y_temp, edgecolors='black')
plt.grid()
plt.xlabel("Latitude")
plt.ylabel("Max Temperature (C)")
plt.title(f"Figure 1: City Max Temperature vs. Latitude \n API request made on {data_time}")

# Save the figure
plt.savefig("output_data/Fig1.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude Vs. Humidity

# %%
# Build the scatter plots for latitude vs. humidity
y_humidity = city_data_df['Humidity']

# Incorporate the other graph properties
fig2 = plt.figure()
plt.scatter(x_lat, y_humidity, edgecolors='black')
plt.grid()
plt.xlabel("Latitude")
plt.ylabel("Humidity (%)")
plt.title(f"Figure 2: City Humidity vs. Latitude \n API request made on {data_time}")

# Save the figure
plt.savefig("output_data/Fig2.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude Vs. Cloudiness

# %%
# Build the scatter plots for latitude vs. cloudiness
y_clouds = city_data_df['Cloudiness']

# Incorporate the other graph properties
fig3 = plt.figure()
plt.scatter(x_lat, y_clouds, edgecolors='black')
plt.grid()
plt.xlabel("Latitude")
plt.ylabel("Cloudiness (%)")
plt.title(f"Figure 3: City Cloudiness vs. Latitude \n API request made on {data_time}")

# Save the figure
plt.savefig("output_data/Fig3.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
# Build the scatter plots for latitude vs. wind speed
y_wind = city_data_df['Wind Speed']

# Incorporate the other graph properties
fig4 = plt.figure()
plt.scatter(x_lat, y_clouds, edgecolors='black')
plt.grid()
plt.xlabel("Latitude")
plt.ylabel("Wind Speed (m/s)")
plt.title(f"Figure 4: City Wind Speed vs. Latitude \n API request made on {data_time}")

# Save the figure
plt.savefig("output_data/Fig4.png")

# Show plot
plt.show()

# %% [markdown]
# ---
#
# ## Requirement 2: Compute Linear Regression for Each Relationship

# %%
# Define a function to create Linear Regression plots
def lat_linregress(x_data, y_data):
    p_slope, p_int, p_r, p_p, p_std_err = linregress(x_data, y_data)
    p_fit = p_slope * x_data + p_int
    plt.scatter(x_data, y_data)
    plt.plot(x_data, p_fit, color='red')
    line_eq = "y = " + str(round(p_slope,2)) + "x + " + str(round(p_int,2))
    plt.annotate(line_eq,(x_data.min(), y_data.max()),fontsize=15,color="red")
    print(f"The r-squared value is: {p_r**2}")
    plt.xlabel('Latitude')
    plt.ylabel(y_data.name)
    plt.title(f"{y_data.name} vs Latitude \n (with linear regression)")

# %%
#lat_linregress(city_data_df['Max Temp'])
lat_linregress(city_data_df['Lat'], city_data_df['Max Temp'])
# Out:
# The r-squared value is: 0.352787793182729

# %%
# Create a DataFrame with the Northern Hemisphere data (Latitude >= 0)
northern_hemi_df = city_data_df.loc[city_data_df['Lat']>=0]

# Display sample data
northern_hemi_df.head()
# Out:
#              City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 0            amga  60.8953  131.9608     -5.88        97         100
# 1          howrah  22.5892   88.3103     30.00        84          40
# 2          guilin  25.2819  110.2864     19.06        90           0
# 3        tazovsky  67.4667   78.7000    -11.20        98          99
# 5           hobyo   5.3505   48.5268     28.81        69         100
#
#          Wind Speed Country        Date
# City_ID
# 0              0.75      RU  1681935785
# 1              3.60      IN  1681935786
# 2              1.07      CN  1681935786
# 3              2.02      RU  1681935487
# 5              5.78      SO  1681935695

# %%
# Create a DataFrame with the Southern Hemisphere data (Latitude < 0)
southern_hemi_df = city_data_df.loc[city_data_df['Lat']<0]

# Display sample data
southern_hemi_df.head()
# Out:
#                    City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 4             grytviken -54.2811  -36.5092      3.33        95         100
# 6          quatre cocos -20.2078   57.7625     26.16        83          40
# 7             adamstown -25.0660 -130.1015     24.90        75          70
# 8              viqueque  -8.8673  126.3658     23.48        89          79
# 9        puerto natales -51.7236  -72.4875     12.25        54          40
#
#          Wind Speed Country        Date
# City_ID
# 4              1.85      GS  1681935482
# 6              6.03      MU  1681935788
# 7              3.55      PN  1681935475
# 8              1.73      TL  1681935788
# 9             13.38      CL  1681935371

# %% [markdown]
# ###  Temperature vs. Latitude Linear Regression Plot

# %%
# Linear regression on Northern Hemisphere
lat_linregress(northern_hemi_df['Lat'], northern_hemi_df['Max Temp'])
# Out:
# The r-squared value is: 0.7409280335876488

# %%
# Linear regression on Southern Hemisphere
lat_linregress(southern_hemi_df['Lat'], southern_hemi_df['Max Temp'])
# Out:
# The r-squared value is: 0.5104509636163055

# %% [markdown]
# **Discussion about the linear relationship:** Maximum Temperature shows a linear relationship to Latitude in each hemisphere, more strongly in the Northern Hemisphere with an r-squared value of ~0.75 than in the Southern Hemisphere at ~0.50.  Interestingly, this data for the Northern Hemisphere subjectively shows a slight curvature, with the highest temperatures occuring at around 15 degrees latitude.  It would be interesting to see if this holds with a much larger data set (and/or if a similar effect might be seen in the Southern Hemisphere with more data), if it has any dependency on Longitude, and if this varies during the year.
#
# ### Humidity vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
lat_linregress(northern_hemi_df['Lat'], northern_hemi_df['Humidity'])
# Out:
# The r-squared value is: 0.04604888691432551

# %%
# Southern Hemisphere
lat_linregress(southern_hemi_df['Lat'], southern_hemi_df['Humidity'])
# Out:
# The r-squared value is: 0.04224550449224674

# %% [markdown]
# **Discussion about the linear relationship:** Only a very weak relationship to Latitude is shown in the Humidity data, with r-squared values each below 0.05.  It is interesting to note, subjectively, that humidity seems to be lowest at about 30 degrees in each hemisphere.

# %% [markdown]
# ### Cloudiness vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
lat_linregress(northern_hemi_df['Lat'], northern_hemi_df['Cloudiness'])
# Out:
# The r-squared value is: 0.02909787671644558

# %%
# Southern Hemisphere
lat_linregress(southern_hemi_df['Lat'], southern_hemi_df['Cloudiness'])
# Out:
# The r-squared value is: 0.005844683302781557

# %% [markdown]
# **Discussion about the linear relationship:** Cloudiness data shows almost no linear relationship to Latitude with r-squared values of ~0.03 and ~0.005.  It might be interesting to plot this versus Humidity instead.

# %% [markdown]
# ### Wind Speed vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
lat_linregress(northern_hemi_df['Lat'], northern_hemi_df['Wind Speed'])
# Out:
# The r-squared value is: 0.0031894726664654332

# %%
# Southern Hemisphere
lat_linregress(southern_hemi_df['Lat'], southern_hemi_df['Wind Speed'])
# Out:
# The r-squared value is: 0.1219623898244387

# %% [markdown]
# **Discussion about the linear relationship:** Wind Speed data shows almost no linear relationship in the Northern Hemisphere, with an r-squared value of ~0.003, and perhaps a very weak relationship in the Southern Hemisphere with an r-suared value of ~0.12.  One might suspect that if the Southern Hemisphere shows a weak linear relationship, that the Northern Hemisphere would as well.  More data points were collected form the Northern Hemisphere in this random selection, so one might suspect that a larger sample in the Southern Hemisphere would show this possible weak relationship to be an artifact of the sampling.  Larger data sets from each hemisphere could help to determine if this relationship is plausible or not.
